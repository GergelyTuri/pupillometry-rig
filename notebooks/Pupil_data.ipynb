# %% [markdown]
# <a href="https://colab.research.google.com/github/GergelyTuri/pupillometry-rig/blob/main/notebooks/Pupil_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Demo notebook for data loading.
# * 3/15/2024 setup

# %%
# !git clone https://github.com/GergelyTuri/pupillometry-rig.git

# %%
# %cd pupillometry-rig
# !pip install .
# Out:
# /content/pupillometry-rig
# Processing /content/pupillometry-rig
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pupillometry: filename=pupillometry-1.0.0-py3-none-any.whl size=13526 sha256=df286e15636b39a993ccc0421bc7500d1623eb15c99326c9d7f5a1c1b65c3492
#   Stored in directory: /root/.cache/pip/wheels/93/14/d3/52584cfbcf2c37f49bd92c2e0a47012d170e23eadb89bc7aa8
# Successfully built pupillometry
# ...

# %%
# %cd pupillometry-rig
# !git pull

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from src import google_drive

# %%
google_drive.useful_datasets()
# Out:
#       mouseID recording_date                           sessionID trialID  \
# 0   sert38b_3      3-23-2022
# 1   sert38b_3      3-23-2022
# 2   sert38b_3      3-23-2022
# 3   sert38b_3      3-23-2022
# 4   sert40b_2      3-23-2022                                         811
# 5   sert40b_2      3-23-2022                                         814
# 6   sert40b_2      3-23-2022                                         821
# 7   sert40b_2      3-23-2022                                         818
# 8   sert40c_1      3-23-2022                                         840
# 9   sert40c_1      3-23-2022                                         850
# 10  sert40c_1      3-23-2022                                         847
# 11  sert40c_5      3-23-2022                                         835
# 12  sert40c_5      3-23-2022                                         830
# 13  sert40c_5      3-23-2022                                         828
# ...
